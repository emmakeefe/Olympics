# %%
#import libraries
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import seaborn as sns
sns.set_palette("colorblind")
palette = sns.color_palette("colorblind")

# %%
#read data into a dataframe
events = pd.read_csv('events.csv')
events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ## The Dataset

# %% [markdown]
# This table contains data on Olympic athletes from 1896-2016, including height, weight, age, sport, event(s), and medal(s) won.
#
# The events table lists all events for all athletes. One athlete might have competed in 3 events during two Games and is therefore listed 6 times. An athlete might have multiple age entries (and possibly height/weight entries, if this info changed from one Games to the next). The ID column is a unique identifier for the athlete and remains the same regardless of event or year.

# %% [markdown]
# ## Find the proportion of entries for each year that have height and weight data

# %% [markdown]
# Let's see how the height and weight data is distributed over the time period (1896-2016).

# %%
#create table with one entry per athlete per games
no_events = events.drop(['Sport', 'Event', 'Team', 'Medal'], axis = 1)
no_events = no_events.drop_duplicates()

# %%
#Find the number of entries per year that have height and weight data
has_data = no_events[(np.isnan(no_events.Weight)==False)&(np.isnan(no_events.Height)==False)].groupby('Year').count()

#Find the number of athletes per year
athletes_per_year = no_events.groupby('Year').ID.count()
has_data = has_data.reset_index()
athletes_per_year = athletes_per_year.reset_index()

has_data['num_athletes'] = athletes_per_year['ID']
has_data.merge(athletes_per_year, on="Year")

#Calculate the proportion of athletes for whom there is weight data, by year
has_data['prop_data'] = has_data.Weight/has_data.num_athletes
has_data.head()
# Out:
#    Year   ID  Name  Sex  Age  Height  Weight  NOC  Games  Season  City  \
# 0  1896   13    13   13   11      13      13   13     13      13    13
# 1  1900   35    35   35   34      35      35   35     35      35    35
# 2  1904   55    55   55   52      55      55   55     55      55    55
# 3  1906   78    78   78   77      78      78   78     78      78    78
# 4  1908  196   196  196  187     196     196  196    196     196   196
#
#    num_athletes  prop_data
# 0           176   0.073864
# 1          1224   0.028595
# 2           650   0.084615
# 3           841   0.092747
# 4          2024   0.096838

# %%
plt.figure(figsize=(15,8))
plt.bar(has_data.Year, has_data.prop_data, color='green', width = 1)
plt.xticks(np.arange(1896, 2020, step=4), rotation=65)
plt.title("Proportion of Athletes per Year for Whom There is Height/Weight Data Available");

# %% [markdown]
# The height and weight data is much more plentiful after 1960. It isn't until 1960 that there is height and weight data available for more than half of the athletes. Height and weight data is very limited for earlier years, with complete info only available for about 17% of entries for athletes in 1932 and 14% for athletes in 1928, compared to 98% for 2016 athletes.

# %% [markdown]
# ## Create a table with one entry per athlete per Games

# %% [markdown]
# This will make measures of things like average height and weight per Games more accurate, as there will be one set of height and weight data per athlete per Games, rather than multiple sets in some cases.

# %%
no_events = events.drop(['Sport', 'Event', 'Team', 'Medal'], axis = 1)
no_events = no_events.drop_duplicates()
no_events.query('Name == "Ioan Popa"')
# Out:
#            ID       Name Sex   Age  Height  Weight  NOC        Games  Year  \
# 191406  96120  Ioan Popa   M  23.0   191.0    75.0  ROU  1976 Summer  1976
# 191407  96120  Ioan Popa   M  27.0   191.0    75.0  ROU  1980 Summer  1980
# 191409  96121  Ioan Popa   M  31.0   171.0    66.0  ROU  1980 Summer  1980
#
#         Season      City
# 191406  Summer  Montreal
# 191407  Summer    Moskva
# 191409  Summer    Moskva

# %% [markdown]
# There should now be some duplicate names/IDs as seen above, but only if that individual took part in multiple Games

# %% [markdown]
# ## How do summer and winter athletes compare in height and weight?

# %%
# %%HTML
#
# <div class='tableauPlaceholder' id='viz1537652388261' style='position: relative'><noscript><a href='#'><img alt='Average Height and Weight by Year, Season ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Av&#47;AverageHeightandWeightbyYearSeason&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='AverageHeightandWeightbyYearSeason&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Av&#47;AverageHeightandWeightbyYearSeason&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1537652388261');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1537652388261' style='position: relative'><noscript><a href='#'><img alt='Average Height and Weight by Year, Season ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Av&#47;AverageHeightandWeightbyYearSeason&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='AverageHeightandWeightbyYearSeason&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Av&#47;AverageHeightandWeightbyYearSeason&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1537652388261');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# Summer athletes tend to weigh more and be taller than winter athletes. There's a dip in height and weight around 1960, after which height and weight climb back up to another peak in 1988/1992, then more or less level off. What about BMI, a measure of tissue mass (muscle, bone, fat) in a person based on their height and weight?

# %% [markdown]
# ## Calculate average BMIs for each Games

# %%
#create a new column with BMI for each athlete
no_events['bmi'] = no_events.Weight/(no_events.Height / 100)**2

#find the averages for bmi for each game and make separate columns for winter averages and summer averages, for 
#easier plotting

summer_bmi = no_events[no_events.Season == "Summer"].groupby('Games').bmi.mean()
winter_bmi = no_events[no_events.Season == "Winter"].groupby('Games').bmi.mean()

#create dataframe with Games as the organizing variable
games = events.groupby('Games', as_index = False).count()
games['num_athletes'] = events.groupby('Games', as_index = False).ID.nunique()

#convert to dataframe then merge to join the series created above to the games table
winter_bmi = pd.DataFrame(winter_bmi)
winter_bmi = winter_bmi.reset_index()
games = games.merge(winter_bmi, on = 'Games', how = 'left')

# %%
games = games.rename({"bmi": "winter_bmi"}, axis = "columns")

# %%
summer_bmi = pd.DataFrame(summer_bmi)
summer_bmi = summer_bmi.reset_index()
games = games.merge(summer_bmi, on = 'Games', how = 'left')

# %%
games = games.rename({"bmi": "summer_bmi"}, axis = "columns")

# %%
plt.figure(figsize=(20,10))
plt.scatter(games.Games, games.summer_bmi, s = 150, c="orange")
plt.scatter(games.Games, games.winter_bmi, s = 150, c="blue")
plt.xticks(rotation = 75)
plt.yticks(np.arange(22.4, 24.4, step=0.2))
plt.title('BMI in Olympic Athletes, 1896-2016')
plt.legend(prop={'size':20});

# %% [markdown]
# Though Summer athletes tend to be taller and weight more, Winter athletes tend to have higher BMIs, suggesting higher muscle (or bone or fat) mass.

# %% [markdown]
# ## Let's look at the number of female athletes per Games and the percentage of female athletes per Games

# %%
#Find the number of female athletes per Games
num_female = events[events.Sex == "F"].groupby('Games').ID.nunique()
num_female = pd.DataFrame(num_female)
num_female = num_female.reset_index()

games = games.merge(num_female, on = "Games", how = 'left')

# %%
games = games.rename({"ID_y" : "num_female"}, axis = 'columns')
games = games.drop([ 'Name', 'Sex', 'Height', 'Weight', 'Team', 'NOC', 'Year','City'], axis = "columns")
games = games.drop(['ID_x', 'Age', 'Sport', 'Event', 'Medal', 'Season'], axis = "columns")

# %%
games['per_female'] = games.num_female/games.num_athletes
games['season'] = games.Games.str.extract('(Summer|Winter)', expand=True)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="Games", y='num_female', data=games)
plt.xticks(rotation = 65, label="Games")
plt.ylabel('Number of Female Athletes')
plt.title('Number of Female Athletes in Olympic Games 1896-2016');

# %%
games.head()
# Out:
#          Games  num_athletes  winter_bmi  summer_bmi  num_female  per_female  \
# 0  1896 Summer           176         NaN   23.508970         NaN         NaN
# 1  1900 Summer          1224         NaN   23.648159        23.0    0.018791
# 2  1904 Summer           650         NaN   23.007338         6.0    0.009231
# 3  1906 Summer           841         NaN   23.255986         6.0    0.007134
# 4  1908 Summer          2024         NaN   23.088836        44.0    0.021739
#
#    season
# 0  Summer
# 1  Summer
# 2  Summer
# 3  Summer
# 4  Summer

# %% [markdown]
# The number of athletes who were female climbed steadily from 0 in the Summer 1896 games to about 5,000 in Summer 2016.

# %%
# %%HTML
#
# <div class='tableauPlaceholder' id='viz1537649902135' style='position: relative'><noscript><a href='#'><img alt='Percentage of Athletes Who Were Female, by Games ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pe&#47;PercentageAthletesFemalebyGames&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='PercentageAthletesFemalebyGames&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pe&#47;PercentageAthletesFemalebyGames&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1537649902135');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1537649902135' style='position: relative'><noscript><a href='#'><img alt='Percentage of Athletes Who Were Female, by Games ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pe&#47;PercentageAthletesFemalebyGames&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='PercentageAthletesFemalebyGames&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pe&#47;PercentageAthletesFemalebyGames&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1537649902135');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [raw]
# Percentages of female athletes have climbed steadily as well. Summer games tend to have slightly higher percentages of female athletes than Winter games, with the exception of 1932-1968, when the reverse was true.

# %%
no_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight  NOC        Games  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1   2                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#    Year  Season       City        bmi
# 0  1992  Summer  Barcelona  24.691358
# 1  2012  Summer     London  20.761246
# 2  1920  Summer  Antwerpen        NaN
# 3  1900  Summer      Paris        NaN
# 4  1988  Winter    Calgary  23.959094

# %%
plt.figure(figsize=(10,10))

sns.boxplot(x=no_events.Sex, y=no_events.Age);

# %% [markdown]
# What sports had the oldest and youngest competitors?

# %%
max_age = no_events.Age.max()
events.query('Age==@max_age')
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
min_age = no_events.Age.min()
events.query('Age==@min_age')
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
mean_age = no_events.groupby('Games').Age.mean()

# %%
plt.figure(figsize = (15, 10))
plt.plot(mean_age);

# %% [markdown]
# look at bmi for a single sport?
# look at number of participants in each sport over the years (when did popularity of a sport trail off)

# %%
events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
wrestling = events.query('Sport=="Wrestling"')

# %%
wrestling = wrestling.drop_duplicates('ID')

# %%
wrestling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4988 entries, 81 to 271099
# Data columns (total 15 columns):
# ID        4988 non-null int64
# Name      4988 non-null object
# Sex       4988 non-null object
# Age       4563 non-null float64
# Height    3546 non-null float64
# Weight    3533 non-null float64
# Team      4988 non-null object
# NOC       4988 non-null object
# Games     4988 non-null object
# Year      4988 non-null int64
# Season    4988 non-null object
# City      4988 non-null object
# Sport     4988 non-null object
# Event     4988 non-null object
# Medal     825 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 623.5+ KB

# %%
no_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight  NOC        Games  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1   2                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#    Year  Season       City        bmi
# 0  1992  Summer  Barcelona  24.691358
# 1  2012  Summer     London  20.761246
# 2  1920  Summer  Antwerpen        NaN
# 3  1900  Summer      Paris        NaN
# 4  1988  Winter    Calgary  23.959094

# %%
wrestling['bmi'] = wrestling.Weight/(wrestling.Height/100)**2

# %%
wrestling.head()
# Out:
#       ID                                  Name Sex   Age  Height  Weight  \
# 81    23                           Fritz Aanes   M  22.0   187.0    89.0
# 137   50                            Arvi Aavik   M  22.0   185.0   106.0
# 186   84                  Stephen Anthony Abas   M  26.0   165.0    55.0
# 192   87          Rost'om Omeris dze Abashidze   M  29.0   188.0    97.0
# 288  155  Mohamed Ibrahim Abd El-Fatah Mohamed   M  22.0   185.0    98.0
#
#               Team  NOC        Games  Year  Season       City      Sport  \
# 81          Norway  NOR  2000 Summer  2000  Summer     Sydney  Wrestling
# 137        Estonia  EST  1992 Summer  1992  Summer  Barcelona  Wrestling
# 186  United States  USA  2004 Summer  2004  Summer     Athina  Wrestling
# 192   Soviet Union  URS  1964 Summer  1964  Summer      Tokyo  Wrestling
# 288          Egypt  EGY  2000 Summer  2000  Summer     Sydney  Wrestling
#
#                                               Event   Medal        bmi
# 81   Wrestling Men's Light-Heavyweight, Greco-Roman     NaN  25.451114
# 137          Wrestling Men's Heavyweight, Freestyle     NaN  30.971512
# 186        Wrestling Men's Featherweight, Freestyle  Silver  20.202020
# 192  Wrestling Men's Light-Heavyweight, Greco-Roman     NaN  27.444545
# 288  Wrestling Men's Light-Heavyweight, Greco-Roman     NaN  28.634039

# %%
plt.scatter(wrestling.Year, wrestling.bmi)

# %%
wrestling.Medal.value_counts()
# Out:
# Bronze    297
# Silver    269
# Gold      259
# Name: Medal, dtype: int64

# %%
wrestling.query('Medal=="Silver"')
# Out:
#             ID                                  Name Sex   Age  Height  \
# 186         84                  Stephen Anthony Abas   M  26.0   165.0
# 590        339              Namiq Yadulla Abdullayev   M  25.0   167.0
# 1173       654                Daniel Aceves Villagrn   M  19.0   158.0
# 2403      1346                        Anselm Ahlfors   M  26.0     NaN
# 2406      1348                  Anders Oscar Ahlgren   M  24.0     NaN
# 2838      1574                         Kosei Akaishi   M  19.0   172.0
# 2962      1650  Bakhtiyar Shakhabutdinovich Akhmedov   M  21.0   190.0
# 3859      2225   Arsen Shakhlamazovich Alakhverdiyev   M  23.0   154.0
# 4765      2722                        Rahim Aliabadi   M  29.0   158.0
# 6558      3673          Olle Henrik Martin Anderberg   M  28.0     NaN
# 7079      3960                Olof Mauritz Andersson   M  21.0     NaN
# 7140      3993                  Thure Elof Andersson   M  29.0     NaN
# 7556      4211     Valeriy Oleksandrovych Andriitsev   M  25.0   181.0
# 8323      4590        Hans Bertil Augustin Antonsson   M  27.0   187.0
# 8628      4737                   Lloyd Otto Appleton   M  22.0     NaN
# 8850      4858   Magomedkhan Suleymanovich Aratsilov   M  29.0   180.0
# 9895      5414                     Migran Arutyunyan   M  27.0   166.0
# 10082     5505                     Marko Tapio Asell   M  26.0   179.0
# 10623     5810                         Joseph Atiyeh   M  27.0     NaN
# 11432     6244                             Ahmet Ayk   M  26.0   178.0
# 12094     6578                             Ion Baciu   M  24.0   165.0
# 13069     7108         Vladimir Nikolayevich Bakulin   M  29.0   156.0
# 13110     7127                         Halit Balamir   M   NaN     NaN
# 13430     7292                           Jzsef Balla   M  20.0   190.0
# 13637     7378                 Stoyan Dimitrov Balov   M  28.0   168.0
# 13700     7418                            Heiko Balz   M  22.0   168.0
# 14542     7827                    Sndor Istvn Brdosi   M  23.0   173.0
# 15620     8409                             Hakk Baar   M  22.0   185.0
# 16160     8700                  Gustave George Bauer   M  20.0     NaN
# 16411     8809                            Henri Baur   M  33.0     NaN
# ...        ...                                   ...  ..   ...     ...
# 238327  119499                 Dimitrios Thanopoulos   M  24.0   178.0
# 239709  120131      Jeffrey James Milton "Jeff" Thue   M  23.0   198.0
# 240030  120288            Soslan Vaznoyevich Tigiyev   M  24.0   172.0
# 240032  120289          Taymuraz Vaznoyevich Tigiyev   M  26.0   185.0
# 240883  120675                    Enyu Dinev Todorov   M  25.0   166.0
# 241052  120738                   Aleksanteri Toivola   M  31.0     NaN
# 241553  120990              Aleksandar Tomov Lazarov   M  23.0   191.0
# 242360  121401                             Istvn Tth   M  28.0   168.0
# 242446  121430          Rustam Stanislavovich Totrov   M  28.0   172.0
# 243730  122064  Vladlen Kostiantynovych Trostianskiy   M  29.0   156.0
# 244276  122329                       Georgios Tsitas   M   NaN     NaN
# 244313  122353                   Ivan Nikolov Tsonov   M  22.0   160.0
# 244484  122412      Georgy Aleksandrovich Tsurtsumia   M  23.0   195.0
# 245114  122745         Daulet Bolatovich Turlykhanov   M  24.0   177.0
# 249862  125129              Zhivko Atanasov Vangelov   M  28.0   173.0
# 250000  125207               Adlan Abuyevich Varayev   M  26.0   170.0
# 250913  125678                       Hans-Jrgen Veil   M  25.0   160.0
# 251466  125928                    Tonya Lynn Verbeek   F  26.0   165.0
# 253952  127166        Richard Lawrence "Dick" Voliva   M  23.0     NaN
# 255296  127806                            Kikuo Wada   M  21.0   169.0
# 258156  129267                  Heinz-Helmut Wehling   M  21.0   165.0
# 259117  129715                          Henri Wernli   M  25.0     NaN
# 259266  129802              August "Gus" Wester, Jr.   M  22.0     NaN
# 263934  132071                                 Xu Li   F  18.0   168.0
# 264175  132201           Nikolay Ivanovich Yakovenko   M  26.0   180.0
# 264783  132506                        Yang Hyeong-Mo   M  25.0   174.0
# 265108  132665                            Selim Yaar   M  26.0   179.0
# 267522  133829                         Nezhdet Zalev   M  23.0   164.0
# 268540  134344                         brahim Zengin   M   NaN     NaN
# 268661  134408      Elmadi Zaynaydiyevich Zhabrailov   M  26.0   182.0
#
#         Weight           Team  NOC        Games  Year  Season            City  \
# 186       55.0  United States  USA  2004 Summer  2004  Summer          Athina
# 590       55.0     Azerbaijan  AZE  1996 Summer  1996  Summer         Atlanta
# 1173      52.0         Mexico  MEX  1984 Summer  1984  Summer     Los Angeles
# 2403       NaN        Finland  FIN  1924 Summer  1924  Summer           Paris
# 2406       NaN         Sweden  SWE  1912 Summer  1912  Summer       Stockholm
# 2838      74.0          Japan  JPN  1984 Summer  1984  Summer     Los Angeles
# 2962     120.0         Russia  RUS  2008 Summer  2008  Summer         Beijing
# 3859      52.0   Soviet Union  URS  1972 Summer  1972  Summer          Munich
# 4765      48.0           Iran  IRI  1972 Summer  1972  Summer          Munich
# 6558       NaN         Sweden  SWE  1948 Summer  1948  Summer          London
# 7079      73.0         Sweden  SWE  1908 Summer  1908  Summer          London
# 7140       NaN         Sweden  SWE  1936 Summer  1936  Summer          Berlin
# 7556      97.0        Ukraine  UKR  2012 Summer  2012  Summer          London
# 8323     100.0         Sweden  SWE  1948 Summer  1948  Summer          London
# 8628       NaN  United States  USA  1928 Summer  1928  Summer       Amsterdam
# 8850      82.0   Soviet Union  URS  1980 Summer  1980  Summer          Moskva
# 9895      67.0        Armenia  ARM  2016 Summer  2016  Summer  Rio de Janeiro
# 10082     82.0        Finland  FIN  1996 Summer  1996  Summer         Atlanta
# 10623     82.0          Syria  SYR  1984 Summer  1984  Summer     Los Angeles
# 11432     97.0         Turkey  TUR  1964 Summer  1964  Summer           Tokyo
# 12094     57.0        Romania  ROU  1968 Summer  1968  Summer     Mexico City
# 13069     52.0   Soviet Union  URS  1968 Summer  1968  Summer     Mexico City
# 13110      NaN         Turkey  TUR  1948 Summer  1948  Summer          London
# 13430    120.0        Hungary  HUN  1976 Summer  1976  Summer        Montreal
# 13637     59.0       Bulgaria  BUL  1988 Summer  1988  Summer           Seoul
# 13700     99.0        Germany  GER  1992 Summer  1992  Summer       Barcelona
# 14542     85.0        Hungary  HUN  2000 Summer  2000  Summer          Sydney
# 15620     97.0         Turkey  TUR  1992 Summer  1992  Summer       Barcelona
# 16160      NaN  United States  USA  1904 Summer  1904  Summer       St. Louis
# 16411      NaN        Austria  AUT  1906 Summer  1906  Summer          Athina
# ...        ...            ...  ...          ...   ...     ...             ...
# 238327    82.0         Greece  GRE  1984 Summer  1984  Summer     Los Angeles
# 239709   118.0         Canada  CAN  1992 Summer  1992  Summer       Barcelona
# 240030    74.0     Uzbekistan  UZB  2008 Summer  2008  Summer         Beijing
# 240032    96.0     Kazakhstan  KAZ  2008 Summer  2008  Summer         Beijing
# 240883    63.0       Bulgaria  BUL  1968 Summer  1968  Summer     Mexico City
# 241052     NaN        Finland  FIN  1924 Summer  1924  Summer           Paris
# 241553   109.0       Bulgaria  BUL  1972 Summer  1972  Summer          Munich
# 242360    62.0        Hungary  HUN  1980 Summer  1980  Summer          Moskva
# 242446    96.0         Russia  RUS  2012 Summer  2012  Summer          London
# 243730    60.0   Soviet Union  URS  1964 Summer  1964  Summer           Tokyo
# 244276     NaN         Greece  GRE  1896 Summer  1896  Summer          Athina
# 244313    54.0       Bulgaria  BUL  1988 Summer  1988  Summer           Seoul
# 244484   120.0     Kazakhstan  KAZ  2004 Summer  2004  Summer          Athina
# 245114    74.0   Soviet Union  URS  1988 Summer  1988  Summer           Seoul
# 249862    65.0       Bulgaria  BUL  1988 Summer  1988  Summer           Seoul
# 250000    74.0   Soviet Union  URS  1988 Summer  1988  Summer           Seoul
# 250913    60.0   West Germany  FRG  1972 Summer  1972  Summer          Munich
# 251466    55.0         Canada  CAN  2004 Summer  2004  Summer          Athina
# 253952     NaN  United States  USA  1936 Summer  1936  Summer          Berlin
# 255296    68.0          Japan  JPN  1972 Summer  1972  Summer          Munich
# 258156    62.0   East Germany  GDR  1972 Summer  1972  Summer          Munich
# 259117     NaN    Switzerland  SUI  1924 Summer  1924  Summer           Paris
# 259266     NaN  United States  USA  1904 Summer  1904  Summer       St. Louis
# 263934    55.0          China  CHN  2008 Summer  2008  Summer         Beijing
# 264175   100.0   Soviet Union  URS  1968 Summer  1968  Summer     Mexico City
# 264783    85.0    South Korea  KOR  1996 Summer  1996  Summer         Atlanta
# 265108    86.0         Turkey  TUR  2016 Summer  2016  Summer  Rio de Janeiro
# 267522    57.0       Bulgaria  BUL  1960 Summer  1960  Summer            Roma
# 268540     NaN         Turkey  TUR  1956 Summer  1956  Summer       Melbourne
# 268661    85.0   Unified Team  EUN  1992 Summer  1992  Summer       Barcelona
#
#             Sport                                           Event   Medal  \
# 186     Wrestling        Wrestling Men's Featherweight, Freestyle  Silver
# 590     Wrestling            Wrestling Men's Flyweight, Freestyle  Silver
# 1173    Wrestling          Wrestling Men's Flyweight, Greco-Roman  Silver
# 2403    Wrestling       Wrestling Men's Bantamweight, Greco-Roman  Silver
# 2406    Wrestling     Wrestling Men's Middleweight B, Greco-Roman  Silver
# 2838    Wrestling        Wrestling Men's Featherweight, Freestyle  Silver
# 2962    Wrestling    Wrestling Men's Super-Heavyweight, Freestyle  Silver
# 3859    Wrestling            Wrestling Men's Flyweight, Freestyle  Silver
# 4765    Wrestling    Wrestling Men's Light-Flyweight, Greco-Roman  Silver
# 6558    Wrestling      Wrestling Men's Featherweight, Greco-Roman  Silver
# 7079    Wrestling       Wrestling Men's Middleweight, Greco-Roman  Silver
# 7140    Wrestling         Wrestling Men's Welterweight, Freestyle  Silver
# 7556    Wrestling          Wrestling Men's Heavyweight, Freestyle  Silver
# 8323    Wrestling          Wrestling Men's Heavyweight, Freestyle  Silver
# 8628    Wrestling         Wrestling Men's Welterweight, Freestyle  Silver
# 8850    Wrestling         Wrestling Men's Middleweight, Freestyle  Silver
# 9895    Wrestling       Wrestling Men's Welterweight, Greco-Roman  Silver
# 10082   Wrestling       Wrestling Men's Welterweight, Greco-Roman  Silver
# 10623   Wrestling          Wrestling Men's Heavyweight, Freestyle  Silver
# 11432   Wrestling    Wrestling Men's Light-Heavyweight, Freestyle  Silver
# 12094   Wrestling       Wrestling Men's Bantamweight, Greco-Roman  Silver
# 13069   Wrestling          Wrestling Men's Flyweight, Greco-Roman  Silver
# 13110   Wrestling            Wrestling Men's Flyweight, Freestyle  Silver
# 13430   Wrestling    Wrestling Men's Super-Heavyweight, Freestyle  Silver
# 13637   Wrestling       Wrestling Men's Bantamweight, Greco-Roman  Silver
# 13700   Wrestling          Wrestling Men's Heavyweight, Freestyle  Silver
# 14542   Wrestling  Wrestling Men's Light-Heavyweight, Greco-Roman  Silver
# 15620   Wrestling  Wrestling Men's Light-Heavyweight, Greco-Roman  Silver
# 16160   Wrestling            Wrestling Men's Flyweight, Freestyle  Silver
# 16411   Wrestling        Wrestling Men's Heavyweight, Greco-Roman  Silver
# ...           ...                                             ...     ...
# 238327  Wrestling       Wrestling Men's Middleweight, Greco-Roman  Silver
# 239709  Wrestling    Wrestling Men's Super-Heavyweight, Freestyle  Silver
# 240030  Wrestling         Wrestling Men's Middleweight, Freestyle  Silver
# 240032  Wrestling          Wrestling Men's Heavyweight, Freestyle  Silver
# 240883  Wrestling        Wrestling Men's Featherweight, Freestyle  Silver
# 241052  Wrestling      Wrestling Men's Featherweight, Greco-Roman  Silver
# 241553  Wrestling  Wrestling Men's Super-Heavyweight, Greco-Roman  Silver
# 242360  Wrestling      Wrestling Men's Featherweight, Greco-Roman  Silver
# 242446  Wrestling        Wrestling Men's Heavyweight, Greco-Roman  Silver
# 243730  Wrestling       Wrestling Men's Bantamweight, Greco-Roman  Silver
# 244276  Wrestling    Wrestling Men's Unlimited Class, Greco-Roman  Silver
# 244313  Wrestling      Wrestling Men's Light-Flyweight, Freestyle  Silver
# 244484  Wrestling  Wrestling Men's Super-Heavyweight, Greco-Roman  Silver
# 245114  Wrestling       Wrestling Men's Welterweight, Greco-Roman  Silver
# 249862  Wrestling      Wrestling Men's Featherweight, Greco-Roman  Silver
# 250000  Wrestling         Wrestling Men's Welterweight, Freestyle  Silver
# 250913  Wrestling       Wrestling Men's Bantamweight, Greco-Roman  Silver
# 251466  Wrestling        Wrestling Women's Lightweight, Freestyle  Silver
# 253952  Wrestling         Wrestling Men's Middleweight, Freestyle  Silver
# 255296  Wrestling          Wrestling Men's Lightweight, Freestyle  Silver
# 258156  Wrestling      Wrestling Men's Featherweight, Greco-Roman  Silver
# 259117  Wrestling          Wrestling Men's Heavyweight, Freestyle  Silver
# 259266  Wrestling         Wrestling Men's Bantamweight, Freestyle  Silver
# 263934  Wrestling        Wrestling Women's Lightweight, Freestyle  Silver
# 264175  Wrestling  Wrestling Men's Light-Heavyweight, Greco-Roman  Silver
# 264783  Wrestling         Wrestling Men's Middleweight, Freestyle  Silver
# 265108  Wrestling    Wrestling Men's Light-Heavyweight, Freestyle  Silver
# 267522  Wrestling         Wrestling Men's Bantamweight, Freestyle  Silver
# 268540  Wrestling         Wrestling Men's Welterweight, Freestyle  Silver
# 268661  Wrestling         Wrestling Men's Middleweight, Freestyle  Silver
#
#               bmi
# 186     20.202020
# 590     19.721037
# 1173    20.829995
# 2403          NaN
# 2406          NaN
# 2838    25.013521
# 2962    33.240997
# 3859    21.926126
# 4765    19.227688
# 6558          NaN
# 7079          NaN
# 7140          NaN
# 7556    29.608376
# 8323    28.596757
# 8628          NaN
# 8850    25.308642
# 9895    24.314124
# 10082   25.592210
# 10623         NaN
# 11432   30.614821
# 12094   20.936639
# 13069   21.367521
# 13110         NaN
# 13430   33.240997
# 13637   20.904195
# 13700   35.076531
# 14542   28.400548
# 15620   28.341855
# 16160         NaN
# 16411         NaN
# ...           ...
# 238327  25.880571
# 239709  30.098969
# 240030  25.013521
# 240032  28.049671
# 240883  22.862534
# 241052        NaN
# 241553  29.878567
# 242360  21.967120
# 242446  32.449973
# 243730  24.654832
# 244276        NaN
# 244313  21.093750
# 244484  31.558185
# 245114  23.620288
# 249862  21.718066
# 250000  25.605536
# 250913  23.437500
# 251466  20.202020
# 253952        NaN
# 255296  23.808690
# 258156  22.773186
# 259117        NaN
# 259266        NaN
# 263934  19.486961
# 264175  30.864198
# 264783  28.075043
# 265108  26.840610
# 267522  21.192742
# 268540        NaN
# 268661  25.661152
#
# [269 rows x 16 columns]

# %% [markdown]
# bmis of gold winning athletes?
